# %% [raw]
# ---
# layout: post
# toc: true
# breadcrumb: true
# categories: [CSSE-2]
# title: CSSE-2 Personal Blog
# description: Reflection on Beginning of Trimester 3
# categories: [CSSE-2]
# permalink: /csse2/blog
# ---

# %%
# %%js
# // GAME_RUNNER: Run the game, user WASD keys to move the player around.
#
# import GameControl from '/assets/js/GameEnginev1/essentials/GameControl.js';
# ...
# export const gameLevelClasses = [CustomLevel];
# export { GameControl };

# %% [markdown]
# # Individual Porfolio
# -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Basketball Game
# -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# %%js
# // GAME_RUNNER: Step 1 — Draw a basketball court using Canvas API
#
# import GameControl from '/assets/js/GameEnginev1/essentials/GameControl.js';
#
# class GameLevelCourt {
#     constructor(gameEnv) {
#         this.classes = [];
#         const W = gameEnv.innerWidth  || window.innerWidth;
#         const H = gameEnv.innerHeight || window.innerHeight;
#         setTimeout(() => this._boot(W, H), 200);
#     }
#     _boot(W, H) {
#         let canvas = document.getElementById('gameCanvas');
#         if (!canvas) { canvas = document.createElement('canvas'); document.body.appendChild(canvas); }
#         canvas.width = W; canvas.height = H;
#         const ctx = canvas.getContext('2d');
#         const drawCourt = () => {
#             const g = ctx.createLinearGradient(0,0,W,0);
#             g.addColorStop(0,'#b5651d'); g.addColorStop(.5,'#cd853f'); g.addColorStop(1,'#b5651d');
#             ctx.fillStyle=g; ctx.fillRect(0,0,W,H);
#             ctx.strokeStyle='rgba(90,40,0,.2)'; ctx.lineWidth=1;
#             for(let x=0;x<W;x+=W/28){ctx.beginPath();ctx.moveTo(x,0);ctx.lineTo(x,H);ctx.stroke();}
#             ctx.strokeStyle='rgba(255,255,255,.7)'; ctx.lineWidth=2;
#             const pad=20;
#             ctx.strokeRect(pad,pad,W-pad*2,H-pad*2);
#             ctx.beginPath();ctx.moveTo(W/2,pad);ctx.lineTo(W/2,H-pad);ctx.stroke();
#             ctx.beginPath();ctx.arc(W/2,H/2,H*.13,0,Math.PI*2);ctx.stroke();
#         };
#         drawCourt();
#     }
# }
# export const gameLevelClasses = [GameLevelCourt];
# export { GameControl };
